# %%
import pandas as pd

# %%
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod1.csv"

# %%
df= pd.read_csv(URL)
df.tail(60)
# Out:
#      Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 178         178       Lenovo         4  IPS Panel    2   1         5
# 179         179       Lenovo         3  IPS Panel    2   1         5
# 180         180           HP         5    Full HD    3   1         7
# 181         181      Toshiba         3  IPS Panel    2   1         5
# 182         182      Samsung         4    Full HD    2   1         7
# 183         183           HP         3    Full HD    2   1         3
# 184         184           HP         3    Full HD    2   1         5
# 185         185           HP         5    Full HD    3   1         7
# 186         186         Dell         4    Full HD    2   1         7
# 187         187      Samsung         4    Full HD    2   1         7
# 188         188         Dell         3    Full HD    1   1         7
# 189         189         Acer         3  IPS Panel    2   1         3
# 190         190         Dell         1    Full HD    3   1         5
# 191         191         Dell         3    Full HD    1   1         3
# 192         192           HP         5    Full HD    3   1         7
# 193         193         Asus         3    Full HD    2   1         5
# 194         194         Dell         4    Full HD    2   1         5
# 195         195      Samsung         4    Full HD    2   1         5
# 196         196         Dell         3    Full HD    1   1         5
# 197         197       Lenovo         4    Full HD    2   1         7
# 198         198          MSI         1    Full HD    3   1         5
# 199         199         Acer         3  IPS Panel    2   1         3
# 200         200       Lenovo         3    Full HD    2   1         5
# 201         201       Lenovo         3  IPS Panel    2   1         5
# 202         202         Dell         3    Full HD    1   1         7
# 203         203       Lenovo         4  IPS Panel    3   1         7
# 204         204         Asus         3  IPS Panel    3   1         7
# 205         205         Dell         3    Full HD    2   1         5
# 206         206           HP         3    Full HD    1   1         5
# 207         207      Toshiba         3    Full HD    2   1         5
# 208         208         Acer         3  IPS Panel    2   1         5
# 209         209      Toshiba         3  IPS Panel    2   1         7
# 210         210      Samsung         4    Full HD    3   1         7
# 211         211         Dell         4    Full HD    2   1         7
# 212         212       Xiaomi         4  IPS Panel    3   1         5
# 213         213           HP         3    Full HD    2   1         5
# 214         214           HP         3    Full HD    2   1         5
# 215         215      Samsung         4    Full HD    2   1         7
# 216         216       Lenovo         4  IPS Panel    2   1         5
# 217         217      Toshiba         3    Full HD    2   1         5
# 218         218         Dell         3    Full HD    2   1         5
# 219         219       Lenovo         3    Full HD    3   1         7
# 220         220           HP         3    Full HD    3   1         7
# 221         221       Lenovo         3    Full HD    2   1         5
# 222         222           HP         3    Full HD    2   1         5
# 223         223           HP         4    Full HD    1   1         7
# 224         224      Toshiba         3  IPS Panel    3   1         7
# 225         225       Lenovo         4  IPS Panel    2   1         7
# 226         226           HP         3    Full HD    2   1         5
# 227         227      Toshiba         3  IPS Panel    2   1         5
# 228         228           HP         2    Full HD    2   1         5
# 229         229         Dell         4    Full HD    2   1         5
# 230         230         Dell         4    Full HD    2   1         5
# 231         231         Dell         4    Full HD    2   1         7
# 232         232      Toshiba         3    Full HD    2   1         5
# 233         233       Lenovo         4  IPS Panel    2   1         7
# 234         234      Toshiba         3    Full HD    2   1         5
# 235         235       Lenovo         4  IPS Panel    2   1         5
# 236         236       Lenovo         3    Full HD    3   1         5
# 237         237      Toshiba         3    Full HD    2   1         5
#
#      Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 178          35.560            2.5       8             256       1.32   1904
# 179          33.020            2.5       8             256       1.44   1219
# 180          39.624            2.8      16             256       2.60   3073
# 181          35.560            2.5       8             256       1.25   1950
# 182          33.782            2.7      16             256       0.81   2095
# 183          39.624            2.0       8             256       1.86    685
# 184          39.624            2.4       8             256       1.84   2414
# 185          39.624            2.6       8             256       2.59   1983
# 186          31.750            2.8      16             256       1.18   2361
# 187             NaN            2.7       8             256       1.31   2031
# 188          39.624            2.7      16             256       2.30   1501
# 189          35.560            2.4       4             128       1.80    808
# 190          39.624            2.5       8             256       2.62   1251
# 191          39.624            2.0       8             256       2.00    939
# 192          39.624            2.8       8             256       3.14   2623
# 193          39.624            2.5       8             256       2.37   1396
# 194          33.782            2.5       8             256       1.29   1904
# 195          33.782            2.5       8             256       0.81   1904
# 196          39.624            2.5       8             256       2.18   1003
# 197          35.560            2.7       8             256       1.32   2361
# 198          39.624            2.5       8             256       2.40   1523
# 199          35.560            2.4       8             128       1.50    786
# 200          35.560            2.3       8             256       1.70   1507
# 201          35.560            2.6       8             256       1.32   2096
# 202          39.624            2.7       4             256       2.18    939
# 203          35.560            2.8       8             256       1.96   2417
# 204          38.100            2.7       8             256       2.30   1000
# 205          39.624            2.5       8             128       1.90   1200
# 206          39.624            2.6       8             256       1.84   1714
# 207          33.782            2.5       4             128       1.05   1632
# 208          35.560            2.5       8             256       1.56   1146
# 209          38.100            2.7       8             256       2.00   1763
# 210          38.100            2.7      16             256       1.23   2349
# 211          31.750            2.8       8             256       1.60   2147
# 212          33.020            2.3       8             256       1.28   1188
# 213          39.624            2.5       4             256       2.04   1066
# 214          35.560            2.5       4             128       1.95   1607
# 215          38.100            2.7       8             256       1.17   2158
# 216          35.560            2.5       8             256       1.32   2285
# 217          33.782            2.5       8             256       1.05   1874
# 218          35.560            2.8       8             256       1.60   1531
# 219          39.624            2.7       6             256       2.20   1002
# 220          39.624            2.7       8             256       2.04   1294
# 221          33.782            2.5       4             128       1.44   1119
# 222          33.782            2.5       8             256       1.49   1219
# 223          39.624            2.5       8             256       1.84   1648
# 224          38.100            2.6      16             256       2.40   2509
# 225          30.480            2.7       8             256       1.36   2096
# 226          39.624            2.3       8             256       2.31   1480
# 227          35.560            2.3       4             128       1.47   1404
# 228          31.750            2.3       8             256       1.26   2120
# 229          35.560            2.5       8             256       1.36   2082
# 230             NaN            2.5       8             256       1.36   1870
# 231          35.560            2.8       8             256       1.36   2255
# 232          33.782            2.3       8             256       1.20   1855
# 233          35.560            2.6       8             256       1.70   1891
# 234          33.782            2.4       8             256       1.20   1950
# 235          30.480            2.6       8             256       1.36   2236
# 236          39.624            2.5       6             256       2.40    883
# 237          35.560            2.3       8             256       1.95   1499

# %%
columns_with_missing_values=df.isnull().any()
columns_with_missing_values
# Out:
# Unnamed: 0        False
# Manufacturer      False
# Category          False
# Screen            False
# GPU               False
# OS                False
# CPU_core          False
# Screen_Size_cm     True
# CPU_frequency     False
# RAM_GB            False
# Storage_GB_SSD    False
# Weight_kg          True
# Price             False
# dtype: bool

# %%
df["Weight_kg"] = df["Weight_kg"].fillna(df["Weight_kg"].mean())

# %%
df
# Out:
#      Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0             0         Acer         4  IPS Panel    2   1         5
# 1             1         Dell         3    Full HD    1   1         3
# 2             2         Dell         3    Full HD    1   1         7
# 3             3         Dell         4  IPS Panel    2   1         5
# 4             4           HP         4    Full HD    2   1         7
# ..          ...          ...       ...        ...  ...  ..       ...
# 233         233       Lenovo         4  IPS Panel    2   1         7
# 234         234      Toshiba         3    Full HD    2   1         5
# 235         235       Lenovo         4  IPS Panel    2   1         5
# 236         236       Lenovo         3    Full HD    3   1         5
# 237         237      Toshiba         3    Full HD    2   1         5
#
#      Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0            35.560            1.6       8             256       1.60    978
# 1            39.624            2.0       4             256       2.20    634
# 2            39.624            2.7       8             256       2.20    946
# 3            33.782            1.6       8             128       1.22   1244
# 4            39.624            1.8       8             256       1.91    837
# ..              ...            ...     ...             ...        ...    ...
# 233          35.560            2.6       8             256       1.70   1891
# 234          33.782            2.4       8             256       1.20   1950
# 235          30.480            2.6       8             256       1.36   2236
# 236          39.624            2.5       6             256       2.40    883
# 237          35.560            2.3       8             256       1.95   1499
#
# [238 rows x 13 columns]

# %%
columns_with_missing_values=df.isnull().any()
columns_with_missing_values
# Out:
# Unnamed: 0        False
# Manufacturer      False
# Category          False
# Screen            False
# GPU               False
# OS                False
# CPU_core          False
# Screen_Size_cm     True
# CPU_frequency     False
# RAM_GB            False
# Storage_GB_SSD    False
# Weight_kg         False
# Price             False
# dtype: bool

# %%
df["Screen_Size_cm"] = df["Screen_Size_cm"].fillna(df["Screen_Size_cm"].mean())

# %%
columns_with_missing_values=df.isnull().any()
columns_with_missing_values
# Out:
# Unnamed: 0        False
# Manufacturer      False
# Category          False
# Screen            False
# GPU               False
# OS                False
# CPU_core          False
# Screen_Size_cm    False
# CPU_frequency     False
# RAM_GB            False
# Storage_GB_SSD    False
# Weight_kg         False
# Price             False
# dtype: bool

# %%
df["Screen_Size_cm"]=df["Screen_Size_cm"].astype(float)

# %%
df["Weight_kg"] = df["Weight_kg"].astype(float)

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# Manufacturer       object
# Category            int64
# Screen             object
# GPU                 int64
# OS                  int64
# CPU_core            int64
# Screen_Size_cm    float64
# CPU_frequency     float64
# RAM_GB              int64
# Storage_GB_SSD      int64
# Weight_kg         float64
# Price               int64
# dtype: object

# %%
df['Screen_Size_inch'] = df['Screen_Size_cm'] / 2.54

# %%
df['Screen_Size_inch']
# Out:
# 0      14.0
# 1      15.6
# 2      15.6
# 3      13.3
# 4      15.6
#        ...
# 233    14.0
# 234    13.3
# 235    12.0
# 236    15.6
# 237    14.0
# Name: Screen_Size_inch, Length: 238, dtype: float64

# %%
df[['Weight_pounds']] = df[['Weight_kg']] * 2.20462

# %%
df[['Weight_pounds']]
# Out:
#      Weight_pounds
# 0         3.527392
# 1         4.850164
# 2         4.850164
# 3         2.689636
# 4         4.210824
# ..             ...
# 233       3.747854
# 234       2.645544
# 235       2.998283
# 236       5.291088
# 237       4.299009
#
# [238 rows x 1 columns]

# %%
df['CPU_frequency'] = df['CPU_frequency'] / df['CPU_frequency'].max()

# %%
df
# Out:
#      Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0             0         Acer         4  IPS Panel    2   1         5
# 1             1         Dell         3    Full HD    1   1         3
# 2             2         Dell         3    Full HD    1   1         7
# 3             3         Dell         4  IPS Panel    2   1         5
# 4             4           HP         4    Full HD    2   1         7
# ..          ...          ...       ...        ...  ...  ..       ...
# 233         233       Lenovo         4  IPS Panel    2   1         7
# 234         234      Toshiba         3    Full HD    2   1         5
# 235         235       Lenovo         4  IPS Panel    2   1         5
# 236         236       Lenovo         3    Full HD    3   1         5
# 237         237      Toshiba         3    Full HD    2   1         5
#
#      Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price  \
# 0            35.560       0.551724       8             256       1.60    978
# 1            39.624       0.689655       4             256       2.20    634
# 2            39.624       0.931034       8             256       2.20    946
# 3            33.782       0.551724       8             128       1.22   1244
# 4            39.624       0.620690       8             256       1.91    837
# ..              ...            ...     ...             ...        ...    ...
# 233          35.560       0.896552       8             256       1.70   1891
# 234          33.782       0.827586       8             256       1.20   1950
# 235          30.480       0.896552       8             256       1.36   2236
# 236          39.624       0.862069       6             256       2.40    883
# 237          35.560       0.793103       8             256       1.95   1499
#
#      Screen_Size_inch  Weight_pounds
# 0                14.0       3.527392
# 1                15.6       4.850164
# 2                15.6       4.850164
# 3                13.3       2.689636
# 4                15.6       4.210824
# ..                ...            ...
# 233              14.0       3.747854
# 234              13.3       2.645544
# 235              12.0       2.998283
# 236              15.6       5.291088
# 237              14.0       4.299009
#
# [238 rows x 15 columns]

# %%
# Convert the 'Screen' attribute into indicator variables
df1 = pd.get_dummies(df['Screen'], prefix='Screen')
# Append df1 into the original data frame df
df = pd.concat([df, df1], axis=1)
# Drop the original 'Screen' attribute from the data frame
df.drop('Screen', axis=1, inplace=True)

# %%
df
# Out:
#      Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_cm  \
# 0             0         Acer         4    2   1         5          35.560
# 1             1         Dell         3    1   1         3          39.624
# 2             2         Dell         3    1   1         7          39.624
# 3             3         Dell         4    2   1         5          33.782
# 4             4           HP         4    2   1         7          39.624
# ..          ...          ...       ...  ...  ..       ...             ...
# 233         233       Lenovo         4    2   1         7          35.560
# 234         234      Toshiba         3    2   1         5          33.782
# 235         235       Lenovo         4    2   1         5          30.480
# 236         236       Lenovo         3    3   1         5          39.624
# 237         237      Toshiba         3    2   1         5          35.560
#
#      CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price  \
# 0         0.551724       8             256       1.60    978
# 1         0.689655       4             256       2.20    634
# 2         0.931034       8             256       2.20    946
# 3         0.551724       8             128       1.22   1244
# 4         0.620690       8             256       1.91    837
# ..             ...     ...             ...        ...    ...
# 233       0.896552       8             256       1.70   1891
# 234       0.827586       8             256       1.20   1950
# 235       0.896552       8             256       1.36   2236
# 236       0.862069       6             256       2.40    883
# 237       0.793103       8             256       1.95   1499
#
#      Screen_Size_inch  Weight_pounds  Screen_Full HD  Screen_IPS Panel
# 0                14.0       3.527392           False              True
# 1                15.6       4.850164            True             False
# 2                15.6       4.850164            True             False
# 3                13.3       2.689636           False              True
# 4                15.6       4.210824            True             False
# ..                ...            ...             ...               ...
# 233              14.0       3.747854           False              True
# 234              13.3       2.645544            True             False
# 235              12.0       2.998283           False              True
# 236              15.6       5.291088            True             False
# 237              14.0       4.299009            True             False
#
# [238 rows x 16 columns]

# %%
df['Price_EUR'] = df['Price'] * 0.88

# %%
df
# Out:
#      Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_cm  \
# 0             0         Acer         4    2   1         5          35.560
# 1             1         Dell         3    1   1         3          39.624
# 2             2         Dell         3    1   1         7          39.624
# 3             3         Dell         4    2   1         5          33.782
# 4             4           HP         4    2   1         7          39.624
# ..          ...          ...       ...  ...  ..       ...             ...
# 233         233       Lenovo         4    2   1         7          35.560
# 234         234      Toshiba         3    2   1         5          33.782
# 235         235       Lenovo         4    2   1         5          30.480
# 236         236       Lenovo         3    3   1         5          39.624
# 237         237      Toshiba         3    2   1         5          35.560
#
#      CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price  \
# 0         0.551724       8             256       1.60    978
# 1         0.689655       4             256       2.20    634
# 2         0.931034       8             256       2.20    946
# 3         0.551724       8             128       1.22   1244
# 4         0.620690       8             256       1.91    837
# ..             ...     ...             ...        ...    ...
# 233       0.896552       8             256       1.70   1891
# 234       0.827586       8             256       1.20   1950
# 235       0.896552       8             256       1.36   2236
# 236       0.862069       6             256       2.40    883
# 237       0.793103       8             256       1.95   1499
#
#      Screen_Size_inch  Weight_pounds  Screen_Full HD  Screen_IPS Panel  \
# 0                14.0       3.527392           False              True
# 1                15.6       4.850164            True             False
# 2                15.6       4.850164            True             False
# 3                13.3       2.689636           False              True
# 4                15.6       4.210824            True             False
# ..                ...            ...             ...               ...
# 233              14.0       3.747854           False              True
# 234              13.3       2.645544            True             False
# 235              12.0       2.998283           False              True
# 236              15.6       5.291088            True             False
# 237              14.0       4.299009            True             False
#
#      Price_EUR
# 0       860.64
# 1       557.92
# 2       832.48
# 3      1094.72
# 4       736.56
# ..         ...
# 233    1664.08
# 234    1716.00
# 235    1967.68
# 236     777.04
# 237    1319.12
#
# [238 rows x 17 columns]

# %%
min_val = df['CPU_frequency'].min()

# %%
min_val
# Out:
# np.float64(0.41379310344827586)

# %%
max_val = df['CPU_frequency'].max()

# %%
max_val
# Out:
# np.float64(1.0)

# %%
normalized_frequency = (df['CPU_frequency'] - min_val) / (max_val - min_val)

# %%
normalized_frequency
# Out:
# 0      0.235294
# 1      0.470588
# 2      0.882353
# 3      0.235294
# 4      0.352941
#          ...
# 233    0.823529
# 234    0.705882
# 235    0.823529
# 236    0.764706
# 237    0.647059
# Name: CPU_frequency, Length: 238, dtype: float64

# %%
df=pd.concat([df, normalized_frequency], axis=1)

# %%
df
# Out:
#      Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_cm  \
# 0             0         Acer         4    2   1         5          35.560
# 1             1         Dell         3    1   1         3          39.624
# 2             2         Dell         3    1   1         7          39.624
# 3             3         Dell         4    2   1         5          33.782
# 4             4           HP         4    2   1         7          39.624
# ..          ...          ...       ...  ...  ..       ...             ...
# 233         233       Lenovo         4    2   1         7          35.560
# 234         234      Toshiba         3    2   1         5          33.782
# 235         235       Lenovo         4    2   1         5          30.480
# 236         236       Lenovo         3    3   1         5          39.624
# 237         237      Toshiba         3    2   1         5          35.560
#
#      CPU_frequency  RAM_GB  Storage_GB_SSD  ...  Screen_Size_inch  \
# 0         0.551724       8             256  ...              14.0
# 1         0.689655       4             256  ...              15.6
# 2         0.931034       8             256  ...              15.6
# 3         0.551724       8             128  ...              13.3
# 4         0.620690       8             256  ...              15.6
# ..             ...     ...             ...  ...               ...
# 233       0.896552       8             256  ...              14.0
# 234       0.827586       8             256  ...              13.3
# 235       0.896552       8             256  ...              12.0
# 236       0.862069       6             256  ...              15.6
# 237       0.793103       8             256  ...              14.0
#
#      Weight_pounds  Screen_Full HD  Screen_IPS Panel  Price_EUR  \
# 0         3.527392           False              True     860.64
# 1         4.850164            True             False     557.92
# 2         4.850164            True             False     832.48
# 3         2.689636           False              True    1094.72
# 4         4.210824            True             False     736.56
# ..             ...             ...               ...        ...
# 233       3.747854           False              True    1664.08
# 234       2.645544            True             False    1716.00
# 235       2.998283           False              True    1967.68
# 236       5.291088            True             False     777.04
# 237       4.299009            True             False    1319.12
#
#      CPU_frequency  CPU_frequency  CPU_frequency  CPU_frequency  CPU_frequency
# 0         0.235294       0.235294       0.235294       0.235294       0.235294
# 1         0.470588       0.470588       0.470588       0.470588       0.470588
# 2         0.882353       0.882353       0.882353       0.882353       0.882353
# 3         0.235294       0.235294       0.235294       0.235294       0.235294
# 4         0.352941       0.352941       0.352941       0.352941       0.352941
# ..             ...            ...            ...            ...            ...
# 233       0.823529       0.823529       0.823529       0.823529       0.823529
# 234       0.705882       0.705882       0.705882       0.705882       0.705882
# 235       0.823529       0.823529       0.823529       0.823529       0.823529
# 236       0.764706       0.764706       0.764706       0.764706       0.764706
# 237       0.647059       0.647059       0.647059       0.647059       0.647059
#
# [238 rows x 22 columns]
